# %%
# data analysis and wrangling
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Reading the data
train_df = pd.read_csv('Train_pjb2QcD.txt', sep = ',', index_col='ID')
test_df = pd.read_csv('Test_wyCirpO.txt', sep = ',', index_col='ID')

# %% [markdown]
# ## Initial Analysis of Data

# %%
# Checking the features available in the dataset

print(train_df.columns.values)
# Out:
# ['Office_PIN' 'Application_Receipt_Date' 'Applicant_City_PIN'
#  'Applicant_Gender' 'Applicant_BirthDate' 'Applicant_Marital_Status'
#  'Applicant_Occupation' 'Applicant_Qualification' 'Manager_DOJ'
#  'Manager_Joining_Designation' 'Manager_Current_Designation'
#  'Manager_Grade' 'Manager_Status' 'Manager_Gender' 'Manager_DoB'
#  'Manager_Num_Application' 'Manager_Num_Coded' 'Manager_Business'
#  'Manager_Num_Products' 'Manager_Business2' 'Manager_Num_Products2'
#  'Business_Sourced']

# %%
train_df.head()
# Out:
#             Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# ID
# FIN1000001      842001                4/16/2007            844120.0
# FIN1000002      842001                4/16/2007            844111.0
# FIN1000003      800001                4/16/2007            844101.0
# FIN1000004      814112                4/16/2007            814112.0
# FIN1000005      814112                4/16/2007            815351.0
#
#            Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# ID
# FIN1000001                M          12/19/1971                        M
# FIN1000002                M           2/17/1983                        S
# FIN1000003                M           1/16/1966                        M
# FIN1000004                M            2/3/1988                        S
# FIN1000005                M            7/4/1985                        M
#
#            Applicant_Occupation Applicant_Qualification Manager_DOJ  \
# ID
# ...

# %%
test_df.head()
# Out:
#             Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# ID
# FIN1009528      284001                 7/2/2008            284001.0
# FIN1009529      800001                 7/2/2008            800026.0
# FIN1009530      800001                 7/2/2008                 NaN
# FIN1009531      800001                 7/2/2008            844112.0
# FIN1009532      533101                 7/2/2008            533102.0
#
#            Applicant_Gender Applicant_BirthDate Applicant_Marital_Status  \
# ID
# FIN1009528                M            8/5/1982                        S
# FIN1009529                M           3/11/1968                        M
# FIN1009530                M          12/16/1984                        S
# FIN1009531                M            6/7/1971                        S
# FIN1009532                M           7/22/1978                        S
#
#            Applicant_Occupation             Applicant_Qualification  \
# ID
# ...

# %%
train_df.info()
print('_'*40)
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9527 entries, FIN1000001 to FIN1009527
# Data columns (total 22 columns):
# Office_PIN                     9527 non-null int64
# Application_Receipt_Date       9527 non-null object
# Applicant_City_PIN             9430 non-null float64
# Applicant_Gender               9460 non-null object
# Applicant_BirthDate            9454 non-null object
# Applicant_Marital_Status       9454 non-null object
# Applicant_Occupation           8306 non-null object
# Applicant_Qualification        9441 non-null object
# Manager_DOJ                    8844 non-null object
# Manager_Joining_Designation    8844 non-null object
# Manager_Current_Designation    8844 non-null object
# Manager_Grade                  8844 non-null float64
# Manager_Status                 8844 non-null object
# Manager_Gender                 8844 non-null object
# Manager_DoB                    8844 non-null object
# Manager_Num_Application        8844 non-null float64
# ...

# %% [markdown]
# **We pre process the dataset and convert categorical variable into numeric variables with help of mapping**

# %%
cleanup_cols={'Applicant_Gender':{'M':1,'F':0},'Manager_Gender':{'M':1,'F':0},'Applicant_Marital_Status':{'S':0,'M':1,'W':2,'D':3},
             'Applicant_Occupation':{'Others':0,'Salaried':1,'Business':2,'Self Employed':3,'Student':4},
             'Applicant_Qualification':{'Others':0,'Class XII':1,'Class X':2,'Graduate':3,'Masters of Business Administration':4,'Associate / Fellow of Institute of Chartered Accountans of India':5,
                                       'Associate/Fellow of Institute of Company Secretories of India':6,'Associate/Fellow of Acturial Society of India':7,'Certified Associateship of Indian Institute of Bankers':8,
                                       'Associate/Fellow of Insurance Institute of India':9,'Professional Qualification in Marketing':10,'Associate/Fellow of Institute of Institute of Costs and Works Accountants of India':11},
              'Manager_Joining_Designation':{'Other':0,'Level 1':1,'Level 2':2,'Level 3':3,'Level 4':4,'Level 5':5,'Level 6':6,'Level 7':7},
              'Manager_Current_Designation':{'Other':0,'Level 1':1,'Level 2':2,'Level 3':3,'Level 4':4,'Level 5':5,'Level 6':6,'Level 7':7},
              'Manager_Status':{'Probation':0,'Confirmation':1}
             }

# %%
# mapping the train dataset
train_df.replace(cleanup_cols, inplace=True)

# %%
# mapping the test dataset
test_df.replace(cleanup_cols, inplace=True)

# %% [markdown]
# ## Univariate Analysis

# %%
train_df['Applicant_Gender'].value_counts()
# Out:
# 1.0    7179
# 0.0    2281
# Name: Applicant_Gender, dtype: int64

# %%
train_df['Applicant_Marital_Status'].value_counts()
# Out:
# 1.0    6177
# 0.0    3267
# 2.0       6
# 3.0       4
# Name: Applicant_Marital_Status, dtype: int64

# %%
train_df['Applicant_Occupation'].value_counts()
# Out:
# 1.0    3787
# 2.0    2303
# 0.0    1966
# 3.0     149
# 4.0     101
# Name: Applicant_Occupation, dtype: int64

# %%
train_df['Applicant_Qualification'].value_counts()
# Out:
# 1     5806
# 3     3196
# 2      225
# 0      132
# 4       74
# 5        3
# 10       1
# 9        1
# 8        1
# 7        1
# 6        1
# Name: Applicant_Qualification, dtype: int64

# %%
train_df['Manager_Gender'].value_counts()
# Out:
# 1.0    7627
# 0.0    1217
# Name: Manager_Gender, dtype: int64

# %%
 train_df['Manager_Joining_Designation'].value_counts()
# Out:
# 1.0    4632
# 2.0    2787
# 3.0    1146
# 4.0     200
# 0.0      58
# 6.0      18
# 7.0       2
# 5.0       1
# Name: Manager_Joining_Designation, dtype: int64

# %%
train_df['Manager_Current_Designation'].value_counts()
# Out:
# 2    3208
# 1    2479
# 3    2033
# 4    1031
# 5      93
# Name: Manager_Current_Designation, dtype: int64

# %%
train_df['Manager_Status'].value_counts()
# Out:
# 1.0    5277
# 0.0    3567
# Name: Manager_Status, dtype: int64

# %% [markdown]
# ## Missing Value Treatment

# %%
#Treating missing values in Train dataset
train_df['Applicant_City_PIN']=train_df['Applicant_City_PIN'].ffill().bfill()
train_df['Applicant_Gender']=train_df['Applicant_Gender'].ffill().bfill()
train_df['Applicant_BirthDate']=train_df['Applicant_BirthDate'].ffill().bfill()
train_df['Applicant_Marital_Status']=train_df['Applicant_Marital_Status'].ffill().bfill()
train_df['Applicant_Occupation']=train_df['Applicant_Occupation'].ffill().bfill()
train_df['Applicant_Qualification']=train_df['Applicant_Qualification'].ffill().bfill()
train_df['Manager_DOJ']=train_df['Manager_DOJ'].ffill().bfill()
train_df['Manager_Joining_Designation']=train_df['Manager_Joining_Designation'].ffill().bfill()
train_df['Manager_Current_Designation']=train_df['Manager_Current_Designation'].ffill().bfill()
train_df['Manager_Grade']=train_df['Manager_Grade'].ffill().bfill()
train_df['Manager_Status']=train_df['Manager_Status'].ffill().bfill()
train_df['Manager_Gender']=train_df['Manager_Gender'].ffill().bfill()
train_df['Manager_DoB']=train_df['Manager_DoB'].ffill().bfill()
train_df['Manager_Num_Application']=train_df['Manager_Num_Application'].ffill().bfill()
train_df['Manager_Business']=train_df['Manager_Business'].fillna(np.mean(train_df['Manager_Business']))
train_df['Manager_Num_Products']=train_df['Manager_Num_Products'].ffill().bfill()
train_df['Manager_Business2']=train_df['Manager_Business2'].fillna(np.mean(train_df['Manager_Business2']))
train_df['Manager_Num_Products2']=train_df['Manager_Num_Products2'].ffill().bfill()
train_df['Manager_Num_Coded']=train_df['Manager_Num_Coded'].ffill().bfill()

# %%
# Treating missing values in Test dataset
test_df['Applicant_City_PIN']=test_df['Applicant_City_PIN'].ffill().bfill()
test_df['Applicant_Gender']=test_df['Applicant_Gender'].ffill().bfill()
test_df['Applicant_BirthDate']=test_df['Applicant_BirthDate'].ffill().bfill()
test_df['Applicant_Marital_Status']=test_df['Applicant_Marital_Status'].ffill().bfill()
test_df['Applicant_Occupation']=test_df['Applicant_Occupation'].ffill().bfill()
test_df['Applicant_Qualification']=test_df['Applicant_Qualification'].ffill().bfill()
test_df['Manager_DOJ']=test_df['Manager_DOJ'].ffill().bfill()
test_df['Manager_Joining_Designation']=test_df['Manager_Joining_Designation'].ffill().bfill()
test_df['Manager_Current_Designation']=test_df['Manager_Current_Designation'].ffill().bfill()
test_df['Manager_Grade']=test_df['Manager_Grade'].ffill().bfill()
test_df['Manager_Status']=test_df['Manager_Status'].ffill().bfill()
test_df['Manager_Gender']=test_df['Manager_Gender'].ffill().bfill()
test_df['Manager_DoB']=test_df['Manager_DoB'].ffill().bfill()
test_df['Manager_Num_Application']=test_df['Manager_Num_Application'].ffill().bfill()
test_df['Manager_Business']=test_df['Manager_Business'].fillna(np.mean(test_df['Manager_Business']))
test_df['Manager_Num_Products']=test_df['Manager_Num_Products'].ffill().bfill()
test_df['Manager_Business2']=test_df['Manager_Business2'].fillna(np.mean(test_df['Manager_Business2']))
test_df['Manager_Num_Products2']=test_df['Manager_Num_Products2'].ffill().bfill()
test_df['Manager_Num_Coded']=test_df['Manager_Num_Coded'].ffill().bfill()

# %%
# Recheck for null values in train dataset
train_df.columns[train_df.isna().any()].tolist()
# Out:
# []

# %%
# Recheck for null values in test dataset
test_df.columns[test_df.isna().any()].tolist()
# Out:
# []

# %% [markdown]
# ## Outlier Treatment

# %%
train_df.loc[train_df['Manager_Business']>650000,'Manager_Business']=np.mean(train_df['Manager_Business'])

# %%
plt.boxplot(train_df['Manager_Business']);

# %%
train_df.loc[train_df['Manager_Business2']>500000,'Manager_Business2']=np.mean(train_df['Manager_Business2'])

# %%
plt.boxplot(train_df['Manager_Business2']);

# %% [markdown]
# ## Modeling

# %%
train_df.head()
# Out:
#             Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# ID
# FIN1000001      842001                4/16/2007            844120.0
# FIN1000002      842001                4/16/2007            844111.0
# FIN1000003      800001                4/16/2007            844101.0
# FIN1000004      814112                4/16/2007            814112.0
# FIN1000005      814112                4/16/2007            815351.0
#
#             Applicant_Gender Applicant_BirthDate  Applicant_Marital_Status  \
# ID
# FIN1000001               1.0          12/19/1971                       1.0
# FIN1000002               1.0           2/17/1983                       0.0
# FIN1000003               1.0           1/16/1966                       1.0
# FIN1000004               1.0            2/3/1988                       0.0
# FIN1000005               1.0            7/4/1985                       1.0
#
#             Applicant_Occupation  Applicant_Qualification Manager_DOJ  \
# ID
# ...

# %%
test_df.head()
# Out:
#             Office_PIN Application_Receipt_Date  Applicant_City_PIN  \
# ID
# FIN1009528      284001                 7/2/2008            284001.0
# FIN1009529      800001                 7/2/2008            800026.0
# FIN1009530      800001                 7/2/2008            800026.0
# FIN1009531      800001                 7/2/2008            844112.0
# FIN1009532      533101                 7/2/2008            533102.0
#
#             Applicant_Gender Applicant_BirthDate  Applicant_Marital_Status  \
# ID
# FIN1009528               1.0            8/5/1982                       0.0
# FIN1009529               1.0           3/11/1968                       1.0
# FIN1009530               1.0          12/16/1984                       0.0
# FIN1009531               1.0            6/7/1971                       0.0
# FIN1009532               1.0           7/22/1978                       0.0
#
#             Applicant_Occupation  Applicant_Qualification Manager_DOJ  \
# ID
# ...

# %% [markdown]
# **Splitting the data and deleting unrequired columns**

# %%
x_train=train_df.drop(['Business_Sourced','Application_Receipt_Date','Applicant_BirthDate','Manager_DOJ','Manager_DoB'],axis=1)

# %%
y_train=train_df['Business_Sourced']

# %%
x_train.head()
# Out:
#             Office_PIN  Applicant_City_PIN  Applicant_Gender  \
# ID
# FIN1000001      842001            844120.0               1.0
# FIN1000002      842001            844111.0               1.0
# FIN1000003      800001            844101.0               1.0
# FIN1000004      814112            814112.0               1.0
# FIN1000005      814112            815351.0               1.0
#
#             Applicant_Marital_Status  Applicant_Occupation  \
# ID
# FIN1000001                       1.0                   0.0
# FIN1000002                       0.0                   0.0
# FIN1000003                       1.0                   2.0
# FIN1000004                       0.0                   1.0
# FIN1000005                       1.0                   0.0
#
#             Applicant_Qualification  Manager_Joining_Designation  \
# ID
# FIN1000001                        3                          1.0
# FIN1000002                        1                          1.0
# ...

# %%
test=test_df.drop(['Application_Receipt_Date','Applicant_BirthDate','Manager_DOJ','Manager_DoB'],axis=1)

# %%
test.head()
# Out:
#             Office_PIN  Applicant_City_PIN  Applicant_Gender  \
# ID
# FIN1009528      284001            284001.0               1.0
# FIN1009529      800001            800026.0               1.0
# FIN1009530      800001            800026.0               1.0
# FIN1009531      800001            844112.0               1.0
# FIN1009532      533101            533102.0               1.0
#
#             Applicant_Marital_Status  Applicant_Occupation  \
# ID
# FIN1009528                       0.0                   1.0
# FIN1009529                       1.0                   1.0
# FIN1009530                       0.0                   1.0
# FIN1009531                       0.0                   1.0
# FIN1009532                       0.0                   1.0
#
#             Applicant_Qualification  Manager_Joining_Designation  \
# ID
# FIN1009528                      3.0                            1
# FIN1009529                      3.0                            1
# ...

# %%
#import libraries
from sklearn.tree import DecisionTreeClassifier
from sklearn.utils import shuffle
import random

# %%
logreg=DecisionTreeClassifier(min_samples_split=170)

# %%
logreg.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=170,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
pred=logreg.predict(test)

# %%
logreg.score(x_train,y_train)
# Out:
# 0.6894090479689304

# %%
test_Business_Sourced=pred

# %%
result={'ID':test.index,'Business_Sourced':pred}
output=pd.DataFrame(result)

# %%
output['Business_Sourced'].value_counts()
# Out:
# 0    3963
# 1    1082
# Name: Business_Sourced, dtype: int64

# %%
output.to_csv('sample_submission.csv',index=False)
